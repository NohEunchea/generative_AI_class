# %%
# 네이버 검색 API 예제 - 블로그 검색
import os
import sys
import urllib.request
client_id = "3hgzBEPVZZTzD5_dyw10"
client_secret = "ckhL0kG8GG"
encText = urllib.parse.quote("엔시티드림")
url = "https://openapi.naver.com/v1/search/blog?query=" + encText + "&start={count}&display=100" # JSON 결과
# url = "https://openapi.naver.com/v1/search/blog.xml?query=" + encText # XML 결과
request = urllib.request.Request(url)
request.add_header("X-Naver-Client-Id",client_id)
request.add_header("X-Naver-Client-Secret",client_secret)
response = urllib.request.urlopen(request)
rescode = response.getcode()
if(rescode==200):
    response_body = response.read()
    print(response_body.decode('utf-8'))
else:
    print("Error Code:" + rescode)
# Out:
# {
# 	"lastBuildDate":"Thu, 28 Mar 2024 10:08:37 +0900",
# 	"total":68902,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"빛의 시어터 <b>엔시티드림<\/b> 전시(시어터오브드림즈) 관람 후기",
# 			"link":"https:\/\/blog.naver.com\/lilcuffs\/223308191885",
# 			"description":"개인적으로 <b>엔시티<\/b> 뮤비들 중에 제일 이쁘게 만들었다고 생각하는 글리치모드 역시 컬러감이 참... <b>드림<\/b>쇼2에 다녀왔으니까요 앙콘이지만 2층 구름다리가 있어서 위에서 내려다 볼 수 도 있음. 엔딩 이후에... ",
# 			"bloggername":"Orangerange",
# 			"bloggerlink":"blog.naver.com\/lilcuffs",
# 			"postdate":"20231231"
# 		},
# 		{
# 			"title":"<b>엔시티드림<\/b> 스무디 팝업스토어 오픈런 웨이팅 럭키드로우 포카... ",
# 			"link":"https:\/\/blog.naver.com\/ggilhee\/223396399295",
# 			"description":"<b>엔시티드림<\/b>팝업 #NCTDREAM #스무디팝업스토어 #<b>엔시티드림<\/b>스무디 #NCTDREAM스무디 #잠실팝업스토어 #잠실팝업 #롯데월드몰팝업 #잠실롯데월드몰 #롯데월드몰팝업스토어 #NCT #NCT팝업 #엔시티팝업스토어",
# 			"bloggername":"길희길희 기억되리",
# 			"bloggerlink":"blog.naver.com\/ggilhee",
# 			"postdate":"20240327"
# 		},
# 		{
# 			"title":"<b>엔시티드림<\/b> 서울 드림쇼 콘서트 공지 nct dream show 3 고척... ",
# ...

# %%
type(response_body)
# Out:
# bytes

# %%
response

# %%
import json
text_data = response_body.decode('utf-8')
print(text_data)
json_data = json.loads(text_data)   #json 형태의 text를 딕셔너리로 바꾸는 코드
print(type(json_data))
# Out:
# {
# 	"lastBuildDate":"Thu, 28 Mar 2024 10:08:37 +0900",
# 	"total":68902,
# 	"start":1,
# 	"display":10,
# 	"items":[
# 		{
# 			"title":"빛의 시어터 <b>엔시티드림<\/b> 전시(시어터오브드림즈) 관람 후기",
# 			"link":"https:\/\/blog.naver.com\/lilcuffs\/223308191885",
# 			"description":"개인적으로 <b>엔시티<\/b> 뮤비들 중에 제일 이쁘게 만들었다고 생각하는 글리치모드 역시 컬러감이 참... <b>드림<\/b>쇼2에 다녀왔으니까요 앙콘이지만 2층 구름다리가 있어서 위에서 내려다 볼 수 도 있음. 엔딩 이후에... ",
# 			"bloggername":"Orangerange",
# 			"bloggerlink":"blog.naver.com\/lilcuffs",
# 			"postdate":"20231231"
# 		},
# 		{
# 			"title":"<b>엔시티드림<\/b> 스무디 팝업스토어 오픈런 웨이팅 럭키드로우 포카... ",
# 			"link":"https:\/\/blog.naver.com\/ggilhee\/223396399295",
# 			"description":"<b>엔시티드림<\/b>팝업 #NCTDREAM #스무디팝업스토어 #<b>엔시티드림<\/b>스무디 #NCTDREAM스무디 #잠실팝업스토어 #잠실팝업 #롯데월드몰팝업 #잠실롯데월드몰 #롯데월드몰팝업스토어 #NCT #NCT팝업 #엔시티팝업스토어",
# 			"bloggername":"길희길희 기억되리",
# 			"bloggerlink":"blog.naver.com\/ggilhee",
# 			"postdate":"20240327"
# 		},
# 		{
# 			"title":"<b>엔시티드림<\/b> 서울 드림쇼 콘서트 공지 nct dream show 3 고척... ",
# ...

# %%
json_data["items"]
# Out:
# [{'title': '빛의 시어터 <b>엔시티드림</b> 전시(시어터오브드림즈) 관람 후기',
#   'link': 'https://blog.naver.com/lilcuffs/223308191885',
#   'description': '개인적으로 <b>엔시티</b> 뮤비들 중에 제일 이쁘게 만들었다고 생각하는 글리치모드 역시 컬러감이 참... <b>드림</b>쇼2에 다녀왔으니까요 앙콘이지만 2층 구름다리가 있어서 위에서 내려다 볼 수 도 있음. 엔딩 이후에... ',
#   'bloggername': 'Orangerange',
#   'bloggerlink': 'blog.naver.com/lilcuffs',
#   'postdate': '20231231'},
#  {'title': '<b>엔시티드림</b> 스무디 팝업스토어 오픈런 웨이팅 럭키드로우 포카... ',
#   'link': 'https://blog.naver.com/ggilhee/223396399295',
#   'description': '<b>엔시티드림</b>팝업 #NCTDREAM #스무디팝업스토어 #<b>엔시티드림</b>스무디 #NCTDREAM스무디 #잠실팝업스토어 #잠실팝업 #롯데월드몰팝업 #잠실롯데월드몰 #롯데월드몰팝업스토어 #NCT #NCT팝업 #엔시티팝업스토어',
#   'bloggername': '길희길희 기억되리',
#   'bloggerlink': 'blog.naver.com/ggilhee',
#   'postdate': '20240327'},
#  {'title': '<b>엔시티드림</b> 서울 드림쇼 콘서트 공지 nct dream show 3 고척... ',
#   'link': 'https://blog.naver.com/5cristal2/223396864894',
# ...
